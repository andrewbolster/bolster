# %% [markdown]
# # Traffic Watch NI Utilities
#
# * Enumerate available cameras
# * Grab images from cameras
# * Combine images into a single grid image
# * Flask service to serve cached images with limited interactivity

# %%
# %pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /Users/bolster/Library/Caches/pypoetry/virtualenvs/bolster-HO2-zZeQ-py3.11/lib/python3.11/site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/bolster/Library/Caches/pypoetry/virtualenvs/bolster-HO2-zZeQ-py3.11/lib/python3.11/site-packages (from beautifulsoup4) (2.5)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup as bs


base_url = "https://www.trafficwatchni.com"
camera_url = f"{base_url}/twni/cameras/"

response = requests.get(camera_url)
soup = bs(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    TrafficWatchNI - Cameras
#   </title>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <!-- <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" /> -->
#   <meta content="width=device-width, initial-scale=1, maximum-scale=500" name="viewport"/>
#   <script src="/twni/javascript/js-cookie/js.cookie.js?v=29092022">
#   </script>
#   <!-- Google Analytics now using Google tag (gtag.js) -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-069FVZSKG2">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# 		  function gtag(){dataLayer.push(arguments);}
# 		  gtag('js', new Date());
#
# 		  gtag('config', 'G-069FVZSKG2');
#   </script>
#   <!-- End Google Analytics -->
#   <link href="/twni/css/fontawesome-all.min.css?v=29092022" rel="stylesheet"/>
#   <link href="/twni/javascript/bootstrap/bootstrap.min.css?v=27062023" rel="stylesheet"/>
#   <script src="/twni/javascript/jquery/jquery-3.7.0.min.js?v=27062023">
#   </script>
#   <script src="/twni/javascript/bootstrap/popper.min.js?v=27062023">
#   </script>
#   <script src="/twni/javascript/bootstrap/bootstrap.min.js?v=27062023">
#   </script>
#   <script src="/twni/javascript/twni/cookie_header.js?v=29092022">
#   </script>
#   <link href="/twni/css/twni.css?v=20241204" rel="stylesheet"/>
#   <meta content="30e03800-72cd-4354-8a57-03981c1e3c81" name="_csrf">
#    <meta content="X-CSRF-TOKEN" name="_csrf_header"/>
#    <!--Check if the requestURI is 'emailsubscription'-->
#    <script>
#     var requestURI = "\/twni\/cameras\/";
#
# 		    if(requestURI.endsWith("/emailsubscription") || requestURI.endsWith("/emailsubscription/")){
# 		    	var recaptchaSiteKey = "6LdKq5gpAAAAAIVj7i4ttbruBRo-q1r_feBgKWW1";
# 		    	script = document.createElement('script');
# 		    	script.src = 'https://www.google.com/recaptcha/api.js?render=' + recaptchaSiteKey;
# 		    	document.head.appendChild(script);
# 		    }
#    </script>
#    <link href="/twni/css/twni-map.css" rel="stylesheet"/>
#    <link href="/twni/javascript/bootstrap-select/bootstrap-multiselect.css?v=29092022"/>
#    <script src="/twni/javascript/bootstrap-multiselect/bootstrap-multiselect.js?v=29092022" type="text/javascript">
#    </script>
#    <script src="/twni/javascript/twni/template.js?v=29092022" type="text/javascript">
#    </script>
#    <script src="/twni/javascript/twni/map.js?v=10072023" type="text/javascript">
#    </script>
#   </meta>
#  </head>
#  <body>
#   <header>
#    <div>
#     <div class="cookie-header p-3 d-none" id="cookie-header">
#      <div class="h3">
#       Cookies on the TrafficwatchNI website
#      </div>
#      <p>
#       This website places small amounts of information known as cookies on
# 			your device.
#      </p>
#      <a href="/twni/cookies">
#       <button class="btn btn-primary-cookies m-1" id="btn-cookie-learn">
#        Learn More
#       </button>
#      </a>
#      <button class="btn btn-info-cookies m-1" id="btn-cookie-accept">
#       Accept
#      </button>
#      <button class="btn btn-info-cookies m-1" id="btn-cookie-deny">
#       Deny
#      </button>
#     </div>
#     <div class="cookie-header p-3 d-none" id="cookie-alternate-header">
#      <div class="h3">
#       Cookies on the TrafficwatchNI website
#      </div>
#      <p>
#       This website places small amounts of information known as cookies on
# 			your device.
#      </p>
#      <button class="btn btn-info-cookies m-1 d-none" id="btn-cookie-give-consent">
#       Give Consent
#      </button>
#      <button class="btn btn-info-cookies-improved m-1 d-none" id="btn-cookie-remove-consent">
#       Remove Consent
#      </button>
#     </div>
#     <!-- Empty Bootstrap Modal used to grey-out background when user has not accepted cookies -->
#     <div class="modal" data-bs-backdrop="static" data-bs-focus="false" data-bs-keyboard="false" id="cookieModal" style="height: 0; width: 0">
#      <div class="modal-dialog">
#       <div class="modal-content">
#       </div>
#      </div>
#     </div>
#    </div>
#    <nav class="navbar navbar-expand-xl navbar-light bg-light" role="navigation">
#     <a accesskey="1" aria-label="Traffic Watch Northern Ireland logo" class="navbar-brand" href="/twni/">
#      <img alt="" src="/twni/images/common/logo-twni.png"/>
#     </a>
#     <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
#      <span class="navbar-toggler-icon">
#      </span>
#     </button>
#     <div class="collapse navbar-collapse" id="navbarNav">
#      <ul class="navbar-nav me-auto">
#       <li class="nav-item">
#        <a class="nav-link d-flex flex-xl-column align-items-center" href="/twni/index" id="navigation_homeLink">
#         <i aria-hidden="true" class="fas fa-home px-2 px-xl-0">
#         </i>
#         <span>
#          Home
#         </span>
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link d-flex flex-xl-column align-items-center" href="/twni/traffic-news" id="navigation_trafficNewsLink">
#         <i aria-hidden="true" class="fas fa-road px-2 px-xl-0">
#         </i>
#         <span>
#          Traffic News
#         </span>
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link d-flex flex-xl-column align-items-center" href="/twni/winter-news">
#         <i aria-hidden="true" class="fas fa-snowflake px-2 px-xl-0">
#         </i>
#         <span>
#          Winter News
#         </span>
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link d-flex flex-xl-column align-items-center" href="/twni/strangford-lough-ferry">
#         <i aria-hidden="true" class="fas fa-ship px-2 px-xl-0">
#         </i>
#         <span>
#          Strangford Lough Ferry
#         </span>
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link d-flex flex-xl-column align-items-center" href="/twni/roadworks">
#         <i aria-hidden="true" class="twni-icon twni-roadwork px-2 px-xl-0">
#         </i>
#         <span>
#          Roadworks
#         </span>
#        </a>
#       </li>
#       <li class="nav-item active">
#        <a class="nav-link d-flex flex-xl-column align-items-center" href="/twni/cameras">
#         <i aria-hidden="true" class="fas fa-camera px-2 px-xl-0">
#         </i>
#         <span>
#          Cameras
#         </span>
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link d-flex flex-xl-column align-items-center" href="/twni/journeytime">
#         <i aria-hidden="true" class="fas fa-stopwatch px-2 px-xl-0">
#         </i>
#         <span>
#          Journey Times
#         </span>
#        </a>
#       </li>
#       <li class="nav-item">
#        <a class="nav-link d-flex flex-xl-column align-items-center" href="https://www.nidirect.gov.uk/information-and-services/travel-transport-and-roads/problems-roads-and-streets" target="_blank">
#         <i aria-hidden="true" class="fas fa-wrench px-2 px-xl-0">
#         </i>
#         <span>
#          Report a Fault
#         </span>
#        </a>
#       </li>
#       <!--<li class="nav-item" th:classappend="${page == 'Weather'} ? 'active' : ''">
#                         <a class="nav-link d-flex flex-xl-column align-items-center" th:href="@{/weather}">
#                             <i class="fas fa-cloud px-2 px-xl-0" aria-hidden="true"></i><span>Weather Stations</span>
#                         </a>
#                     </li>-->
#       <li class="nav-item dropdown">
#        <a class="nav-link d-flex flex-xl-column align-items-center" data-bs-toggle="dropdown" id="navbarDropdown">
#         <i aria-hidden="true" class="fas fa-question-circle px-2 px-xl-0">
#         </i>
#         <span aria-haspopup="true" class="dropdown-toggle">
#          About
#         </span>
#        </a>
#        <div aria-expanded="false" aria-labelledby="navbarDropdown" class="dropdown-menu">
#         <a class="dropdown-item" href="/twni/about-twni">
#          About Traffic Watch NI
#         </a>
#         <a class="dropdown-item" href="/twni/traffic-info-and-control-centre">
#          Traffic Information and Control Centre
#         </a>
#         <a class="dropdown-item" href="/twni/intelligent-transport-systems-its">
#          Intelligent Transport Systems (ITS)
#         </a>
#         <a class="dropdown-item" href="/twni/managing-the-network">
#          Managing the Network
#         </a>
#         <a class="dropdown-item" href="/twni/traffic-and-travel-information">
#          Traffic and Travel Information
#         </a>
#         <a class="dropdown-item" href="/twni/liaison-with-others">
#          Liaison with Others
#         </a>
#        </div>
#       </li>
#      </ul>
#      <div class="navbar-right">
#       <div class="row justify-content-center">
#        <div class="col-auto">
#         <a href="https://www.infrastructure-ni.gov.uk/">
#          <img alt="Department for Infrastructure" class="dfi-logo" src="/twni/images/common/logo-infrastructure-ni.png"/>
#         </a>
#        </div>
#       </div>
#       <div class="row mt-3 navbar-social-media">
#        <div class="col-sm-3 col-xl-6 navbar-social-media-icon">
#        </div>
#        <div class="col-sm-2 navbar-social-media-icon">
#         <a aria-label="Subscribe to email alerts" href="/twni/emailsubscription" title="Subscribe to email alerts">
#          <i aria-hidden="true" class="fas fa-2x fa-envelope">
#          </i>
#         </a>
#        </div>
#        <div class="col-sm-2 navbar-social-media-icon">
#         <a aria-label="RSS feeds" href="/twni/rss-faqs" title="RSS feeds">
#          <i aria-hidden="true" class="fa fa-2x fa-rss ps-1">
#          </i>
#         </a>
#        </div>
#        <div class="col-sm-2 navbar-social-media-icon" style="display: flex; justify-content: center; align-items: center;">
#         <a aria-label="Traffic Watch Northern Ireland on X" class="twitter-social-media-link" href="https://twitter.com/TrafficWatchNI" target="_blank" title="Traffic Watch Northern Ireland on X">
#          <img alt="Twitter Logo" class="twitter-social-media-icon" src="/twni/images/common/twitter-logo-black.png"/>
#         </a>
#        </div>
#        <div class="col-sm-3 d-xl-none navbar-social-media-icon">
#        </div>
#       </div>
#      </div>
#     </div>
#    </nav>
#   </header>
#   <div class="container-fluid" id="content" name="content" role="main">
#    <h1>
#     Cameras
#    </h1>
#    <div>
#     <nav aria-label="Camera Navigation" class="navbar navbar-expand navbar-light bg-light px-3 py-0">
#      <span class="navbar-brand no-border-end" style="font-size: 1rem;">
#       View by:
#      </span>
#      <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarSupportedContent" data-bs-toggle="collapse" type="button">
#       <span class="navbar-toggler-icon">
#       </span>
#      </button>
#      <div class="collapse navbar-collapse" id="navbarSupportedContent" style="border-start: 0px;">
#       <ul class="navbar-nav me-auto">
#        <li class="no-border-end nav-item active">
#         <a class="nav-link" href="?viewby=region">
#          Region
#          <span class="visually-hidden">
#           (current)
#          </span>
#         </a>
#        </li>
#        <li class="no-border-end nav-item">
#         <a class="nav-link" href="?viewby=road">
#          Road
#         </a>
#        </li>
#        <li class="no-border-end nav-item">
#         <a class="nav-link" href="?viewby=mapCheck&amp;d=CCTV_CAMERAS">
#          Map
#         </a>
#        </li>
#       </ul>
#       <ul class="navbar-nav">
#        <li class="no-border-end nav-item dropdown">
#         <a aria-expanded="false" aria-haspopup="true" aria-label="Camera Groups Dropdown" class="nav-link btn dropdown-toggle" data-bs-toggle="dropdown" id="cameraNavbarDropdown" role="button">
#          Groups
#         </a>
#         <div aria-labelledby="navbarDropdown" class="dropdown-menu dropdown-menu-right p-2">
#          <div class="form-check">
#           <input checked="checked" class="form-check-input" data-groupid="group2" id="cb_group2" type="checkbox"/>
#           <label class="form-check-label" for="cb_group2">
#            Greater Belfast
#           </label>
#          </div>
#          <div class="form-check">
#           <input checked="checked" class="form-check-input" data-groupid="group3" id="cb_group3" type="checkbox"/>
#           <label class="form-check-label" for="cb_group3">
#            North East
#           </label>
#          </div>
#          <div class="form-check">
#           <input checked="checked" class="form-check-input" data-groupid="group5" id="cb_group5" type="checkbox"/>
#           <label class="form-check-label" for="cb_group5">
#            North West
#           </label>
#          </div>
#          <div class="form-check">
#           <input checked="checked" class="form-check-input" data-groupid="group4" id="cb_group4" type="checkbox"/>
#           <label class="form-check-label" for="cb_group4">
#            South East
#           </label>
#          </div>
#          <div class="form-check">
#           <input checked="checked" class="form-check-input" data-groupid="group6" id="cb_group6" type="checkbox"/>
#           <label class="form-check-label" for="cb_group6">
#            South West
#           </label>
#          </div>
#         </div>
#        </li>
#       </ul>
#      </div>
#     </nav>
#    </div>
#    <p>
#     Camera images are available to view below. Click on the link to display the latest images, or view the location of the cameras on the map.
#    </p>
#    <div id="cctvSelection">
#     <div class="camera-group-container" data-index="0" id="group2">
#      <div class="camera-group-header d-flex justify-content-between">
#       <div class="camera-group-name">
#        Greater Belfast
#       </div>
#       <div class="align-middle" id="closeButton0">
#        <button aria-label="Close" class="close no-float" type="button" value="group2">
#         <span aria-hidden="true">
#          ×
#         </span>
#        </button>
#       </div>
#      </div>
#      <div class="camera-group-row">
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="44">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=44" id="cameraLink" title="View camera : A2 - Tillysburn">
#           A2 - Tillysburn
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=44', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : A2 - Tillysburn"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(44, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "3260.jpg", "A2 - Tillysburn")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="45">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=45" id="cameraLink" title="View camera : A2 - Holywood Esplanade">
#           A2 - Holywood Esplanade
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=45', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : A2 - Holywood Esplanade"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(45, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "3261.jpg", "A2 - Holywood Esplanade")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="9">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=9" id="cameraLink" title="View camera : A12 Clifton Street">
#           A12 Clifton Street
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=9', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : A12 Clifton Street"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(9, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "8.jpg", "A12 Clifton Street")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="10">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=10" id="cameraLink" title="View camera : A12 Roden Street">
#           A12 Roden Street
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=10', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : A12 Roden Street"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(10, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "4.jpg", "A12 Roden Street")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="171">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=171" id="cameraLink" title="View camera : M1 - Stockmans Lane">
#           M1 - Stockmans Lane
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=171', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : M1 - Stockmans Lane"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(171, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "106.jpg", "M1 - Stockmans Lane")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="43">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=43" id="cameraLink" title="View camera : Saintfield Road - Primrose Hill">
#           Saintfield Road - Primrose Hill
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=43', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Saintfield Road - Primrose Hill"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(43, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "3259.jpg", "Saintfield Road - Primrose Hill")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="191">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=191" id="cameraLink" title="View camera : Upper Knockbreda Rd - Cregagh Rd">
#           Upper Knockbreda Rd - Cregagh Rd
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=191', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Upper Knockbreda Rd - Cregagh Rd"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(191, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "404.jpg", "Upper Knockbreda Rd - Cregagh Rd")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="156">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=156" id="cameraLink" title="View camera : East Bridge Street - Central Station">
#           East Bridge Street - Central Station
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=156', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : East Bridge Street - Central Station"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(156, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "21.jpg", "East Bridge Street - Central Station")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="11">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=11" id="cameraLink" title="View camera : M1 Broadway">
#           M1 Broadway
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=11', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : M1 Broadway"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(11, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "3.jpg", "M1 Broadway")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="190">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=190" id="cameraLink" title="View camera : Ballygowan Road - Knock Road">
#           Ballygowan Road - Knock Road
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=190', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Ballygowan Road - Knock Road"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(190, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "402_1.jpg", "Ballygowan Road - Knock Road")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="54">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=54" id="cameraLink" title="View camera : Boucher Road - Tates Avenue">
#           Boucher Road - Tates Avenue
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=54', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Boucher Road - Tates Avenue"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(54, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "3270.jpg", "Boucher Road - Tates Avenue")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="3">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=3" id="cameraLink" title="View camera : Shaftesbury Square">
#           Shaftesbury Square
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=3', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Shaftesbury Square"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(3, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "16.jpg", "Shaftesbury Square")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="201">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=201" id="cameraLink" title="View camera : Durham St - College Sq Nth">
#           Durham St - College Sq Nth
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=201', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Durham St - College Sq Nth"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(201, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "10_1.jpg", "Durham St - College Sq Nth")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="208">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=208" id="cameraLink" title="View camera : M2 - Fortwilliam North (1B16)">
#           M2 - Fortwilliam North (1B16)
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=208', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : M2 - Fortwilliam North (1B16)"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(208, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "207.jpg", "M2 - Fortwilliam North (1B16)")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="211">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=211" id="cameraLink" title="View camera : Upp K'Breda - Milltown Rd">
#           Upp K'Breda - Milltown Rd
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=211', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Upp K'Breda - Milltown Rd"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick="addToPreview(211, &quot;https:\/\/cctv.trafficwatchni.com&quot;, &quot;1734545910000&quot;, &quot;407.jpg&quot;, &quot;Upp K'Breda - Milltown Rd&quot;)" title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="48">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=48" id="cameraLink" title="View camera : Knock Road - Upper Newtownards Road">
#           Knock Road - Upper Newtownards Road
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=48', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Knock Road - Upper Newtownards Road"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(48, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "3264.jpg", "Knock Road - Upper Newtownards Road")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="28">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=28" id="cameraLink" title="View camera : Falls Road - Donegall Road">
#           Falls Road - Donegall Road
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=28', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Falls Road - Donegall Road"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(28, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "3244.jpg", "Falls Road - Donegall Road")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="36">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=36" id="cameraLink" title="View camera : M2 - Greencastle - Jct 2">
#           M2 - Greencastle - Jct 2
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=36', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : M2 - Greencastle - Jct 2"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(36, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "3252.jpg", "M2 - Greencastle - Jct 2")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="204">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=204" id="cameraLink" title="View camera : Ormeau AV - Linehall ST">
#           Ormeau AV - Linehall ST
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=204', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Ormeau AV - Linehall ST"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(204, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "30.jpg", "Ormeau AV - Linehall ST")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="151">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=151" id="cameraLink" title="View camera : Oxford Street - Ann Street">
#           Oxford Street - Ann Street
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=151', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Oxford Street - Ann Street"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(151, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "2_1.jpg", "Oxford Street - Ann Street")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="162">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=162" id="cameraLink" title="View camera : Falls Road - Grosvenor Road">
#           Falls Road - Grosvenor Road
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=162', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Falls Road - Grosvenor Road"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(162, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "40_1.jpg", "Falls Road - Grosvenor Road")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="4">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=4" id="cameraLink" title="View camera : M1 Sprucefield">
#           M1 Sprucefield
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=4', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : M1 Sprucefield"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(4, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "6.jpg", "M1 Sprucefield")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="160">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=160" id="cameraLink" title="View camera : University Road - Stranmillis Road">
#           University Road - Stranmillis Road
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=160', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : University Road - Stranmillis Road"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(160, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "33.jpg", "University Road - Stranmillis Road")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="153">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=153" id="cameraLink" title="View camera : Victoria Street - High Street">
#           Victoria Street - High Street
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=153', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Victoria Street - High Street"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick='addToPreview(153, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "5_1.jpg", "Victoria Street - High Street")' title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="50">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=50" id="cameraLink" title="View camera : Belvoir C'way - Newtownbreda Rd - Tesco's">
#           Belvoir C'way - Newtownbreda Rd - Tesco's
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=50', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Belvoir C'way - Newtownbreda Rd - Tesco's"/>
#          </button>
#          <!-- Button -->
#          <button class="cameraPreviewAdd" onclick="addToPreview(50, &quot;https:\/\/cctv.trafficwatchni.com&quot;, &quot;1734545910000&quot;, &quot;3266.jpg&quot;, &quot;Belvoir C'way - Newtownbreda Rd - Tesco's&quot;)" title="Click here to add this camera to the Favourites Panel">
#           <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="p-2 col-12 col-sm-6 col-md-4 col-lg-3 col-xl-2 cameraFragment" data-cctv-id="33">
#        <div class="cctvOption">
#         <div class="imgrotate" id="imgrotate">
#          <!-- First Link -->
#          <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=33" id="cameraLink" title="View camera : M1 - Blacks Rd - Jct 3">
#           M1 - Blacks Rd - Jct 3
#          </a>
#          <!-- Clickable Link -->
#          <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=33', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
#           <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : M1 - Blacks Rd - Jct 3"/>
#          </button>
#          <!-- Button -->
# ...
#                 top: 50%;
#                 transform: translateY(-50%);
#             }
#
#             #previewCameraCarouselNextButton {
#                 right:10vw;
#                 top: 50%;
#                 transform: translateY(-50%);
#             }
#
#             #previewCameraCarouselCurrentImage {
#                 position: absolute;
#                 top: 50%;
#                 left: 50%;
#                 transform: translate(-50%, -50%);
#                 width:auto;
#                 height:auto;
#                 max-height:50vh;
#                 max-width:70vw;
#             }
#
#             #previewCameraCarouselTitle {
#                 transform: translate(-50%, -50%);
#                 left: 50%;
#                 bottom: 10%;
#                 background-color: rgba(0,0,0,0.5);
#             }
#
#             @media only screen and (max-width: 600px) {
#
# 	            .preview-item {
# 	                margin-left:auto;
# 	                margin-right:auto;
# 	            }
#
# 	            #previewCameraCarouselCurrentImage {
# 	                max-height:90vh;
# 	                max-width:100vw;
# 	                min-width:80vw;
# 	            }
#
# 	            #previewCameraCarouselTitle {
# 	                font-size:1.1rem;
# 	            }
#
#             }
#      </style>
#      <script>
#       let isPreviewOpen = false;
#             const PREVIEW_REFRESH_INTERVAL_SECONDS = 1;
#             const KEEP_OPEN_SECONDS = 3600;
#
#             function togglePreviewCamera() {
#                 let previewContainer = document.getElementById("previewCameraContainer");
#                 let button = document.querySelector('.floating-button');
#
#                 if (previewContainer.classList.contains("visible")) {
#                     // Hide the preview container and show the button
#                     previewContainer.classList.remove("visible");
#                     previewContainer.classList.add("hidden");
#                     button.classList.remove('open');
#                     button.classList.remove('hidden');
#                 } else {
#                     // Show the preview container and hide the button
#                     previewContainer.classList.remove("hidden");
#                     previewContainer.classList.add("visible");
#                     button.classList.add('open');
#                     setTimeout(() => {
#                         button.classList.add('hidden');
#                     }, 300); // Adjust the timeout to match the transition duration
#                     //isPreviewOpen = true;
#                 }
#
#                 // Update aria properties based on expansion state
#                 previewContainer.setAttribute("aria-expanded", previewContainer.classList.contains("visible") ? "true" : "false");
#                 updateCameraPreviews();
#             }
#
#
#             function showPreviewCamera( isExpanded ) {
#                 let previewContainer = document.getElementById("previewCameraContainer");
#                 let button = document.querySelector('.floating-button');
#                 if (previewContainer.classList.contains("hidden")) {
#                     // Ensure the preview container is always visible
#                     previewContainer.classList.remove("hidden");
#                     previewContainer.classList.add("visible");
#                 }
#
#                 isPreviewOpen = isExpanded;
#
#                 // Update aria properties to reflect the container is expanded
#                 previewContainer.setAttribute("aria-expanded", "true");
#                 updateCameraPreviews();
#             }
#
#             function removeFromPreview(id) {
#                 let cameraPreviewList = JSON.parse(Cookies.get('cameraPreviewList') ?? null) ?? [];
#
#                 cameraPreviewList = cameraPreviewList.filter(camera => camera.id!==id);
#                 Cookies.set('cameraPreviewList', JSON.stringify(cameraPreviewList), { expires: 7300 });
#                 updateCameraPreviews();
#             }
#
#             function closeCarousel() {
#                 let carouselContainer = document.getElementById("previewCameraCarousel");
#                 carouselContainer.classList.add("hidden");
#             }
#
#             function rotateImage(element, isHover) {
#                 // Find the button within the imgrotate div
#                 const button = element.querySelector('.cameraPreviewAdd');
#
#                 if (button) {
#                     const img = button.querySelector('img');
#                     if (img) {
#                         if (isHover) {
#                             changeImage(img, '/twni/images/pages/wired-outline-49-plus-circle-rotate.gif');
#                         } else {
#                             changeImage(img, '/twni/images/pages/wired-outline-49-plus-circle-static.png');
#                         }
#                     } else {
#                         console.log('No image found inside the button.');
#                     }
#                 } else {
#                     console.log('No button found inside the imgrotate div.');
#                 }
#             }
#
#             function changeImage(imgElement, newSrc) {
# 			    imgElement.src = newSrc;
# 			}
#
#             // Every x seconds (PREVIEW_REFRESH_INTERVAL_SECONDS), update the preview cameras including enlarged carousel versions) using a cache breaker
#             function refreshPreviews() {
#
#                 // check if the preview drawer is open, no need to refresh if it is now
#                 if (isPreviewOpen === true) {
#                     // Loop through all of the elements representing a preview
#                     let cameraPreviews = [...document.getElementsByClassName("preview-image"), document.getElementById("previewCameraCarouselCurrentImage")];
#
#                     for (let i=0;i<cameraPreviews.length; i++) {
#                         let previewImage = cameraPreviews[i];
#                         // Remove existing cache breakers from the url
#                         let previewImageSrc = previewImage.src.split("#")[0].split("?")[0];
#                         if (previewImageSrc) {
#                             // amend the image src using a timestamp at the end (cache breaker), this should force a refresh
#                             previewImageSrc = `${previewImageSrc}?${Date.now()}`;
#                             previewImage.src = previewImageSrc;
#                         }
#                     }
#
#                     // Auto-close the drawer if the limit exceeded
#                     let carouselContainer = document.getElementById("previewCameraContainer");
#                     let opened = carouselContainer.getAttribute("date-opened");
#                     if (Date.now() - opened > (KEEP_OPEN_SECONDS * 1000)) {
#                         //togglePreviewCamera();
#                     }
#
#
#                 }
#
#                	setTimeout(refreshPreviews, PREVIEW_REFRESH_INTERVAL_SECONDS*1000);
#
#             }
#
#             function openCarousel(id) {
#                 let cameraPreviewList = JSON.parse(Cookies.get('cameraPreviewList') ?? null) ?? [];
#
#                 let carouselCurrentImage = document.getElementById("previewCameraCarouselCurrentImage");
#                 let carouselContainer = document.getElementById("previewCameraCarousel");
#                 let carouselTitle = document.getElementById("previewCameraCarouselTitle");
#                 let newCarouselImageSrc;
#                 let newCarouselTitle;
#
#                 // Get the image url for the id given
#                 cameraPreviewList.forEach(camera => {
#                     if (camera.id === id) {
#                         newCarouselImageSrc = camera.imageRoot + '/' + camera.staticFile + '?cache=' + camera.cameraCache;
#                         newCarouselTitle = camera.location;
#                     }
#                 });
#
#                 // If the passed id isn't a preview image, do nothing and keep the carousel closed
#                 if (typeof(newCarouselImageSrc) === 'undefined') {
#                     return;
#                 }
#
#                 carouselCurrentImage.dataset.id = id;
#                 carouselCurrentImage.src = newCarouselImageSrc;
#                 carouselTitle.innerHTML = newCarouselTitle;
#                 carouselContainer.classList.remove("hidden");
#             }
#
#             function carouselNext() {
#                 let cameraPreviewList = JSON.parse(Cookies.get('cameraPreviewList') ?? null) ?? [];
#
#                 let carouselCurrentImage = document.getElementById("previewCameraCarouselCurrentImage");
#                 let carouselTitle = document.getElementById("previewCameraCarouselTitle");
#                 let newCarouselImageSrc;
#
#                 // Get the index of the current camera being displayed
#                 let currentDisplayedId = carouselCurrentImage.dataset.id;
#                 let currentDisplayedIndex = -1;
#                 for (let i=0; i<cameraPreviewList.length; i++) {
#                     if (cameraPreviewList[i].id == currentDisplayedId) {
#                         currentDisplayedIndex = i;
#                         break;
#                     }
#                 }
#
#                 let newDisplayedIndex = currentDisplayedIndex+1;
#                 // Move to the next image, wrapping around to 0 if out of bounds
#                 if (newDisplayedIndex>=cameraPreviewList.length) {
#                     newDisplayedIndex = 0;
#                 }
#
#                 let newPreviewCamera = cameraPreviewList[newDisplayedIndex];
#                 let newPreviewCameraSrc = newPreviewCamera.imageRoot + '/' + newPreviewCamera.staticFile + '?cache=' + newPreviewCamera.cameraCache
#                 carouselCurrentImage.dataset.id = newPreviewCamera.id;
#                 carouselTitle.innerHTML = newPreviewCamera.location;
#                 carouselCurrentImage.src = newPreviewCameraSrc;
#
#             }
#
#             function carouselPrevious() {
#                 let cameraPreviewList = JSON.parse(Cookies.get('cameraPreviewList') ?? null) ?? [];
#
#                 let carouselCurrentImage = document.getElementById("previewCameraCarouselCurrentImage");
#                 let carouselTitle = document.getElementById("previewCameraCarouselTitle");
#                 let newCarouselImageSrc;
#
#                 // Get the index of the current camera being displayed
#                 let currentDisplayedId = carouselCurrentImage.dataset.id;
#                 let currentDisplayedIndex = -1;
#                 for (let i=0; i<cameraPreviewList.length; i++) {
#                     if (cameraPreviewList[i].id == currentDisplayedId) {
#                         currentDisplayedIndex = i;
#                         break;
#                     }
#                 }
#
#                 let newDisplayedIndex = currentDisplayedIndex-1;
#                 // Move to the previous image, wrapping around to maximum if out of bounds
#                 if (newDisplayedIndex<0) {
#                     newDisplayedIndex = cameraPreviewList.length-1;
#                 }
#
#                 let newPreviewCamera = cameraPreviewList[newDisplayedIndex];
#                 let newPreviewCameraSrc = newPreviewCamera.imageRoot + '/' + newPreviewCamera.staticFile + '?cache=' + newPreviewCamera.cameraCache
#                 carouselCurrentImage.dataset.id = newPreviewCamera.id;
#                 carouselTitle.innerHTML = newPreviewCamera.location;
#                 carouselCurrentImage.src = newPreviewCameraSrc;
#             }
#
#
#             refreshPreviews();
#
#
#
#
#             /*
#             // Run functions on load
# 			window.onload = () => {
#                 // Check if cookies are disabled to hide preview drawer
#                 if (Cookies.get('cookieConsent') !== "true") {
#                     let previewDrawer = document.getElementById("previewCameraContainer");
#                     previewDrawer.classList.add("disabled");
#                 } else {
#                     // Run the refresh function once to start its looping
#                     refreshPreviews();
#                 }
#             }
# 			*/
#      </script>
#      <script src="/twni/javascript/twni/preview_drawer.js?v=20241204">
#      </script>
#      <script src="/twni/javascript/twni/message.js?v=20240916">
#      </script>
#      <meta content="public" http-equiv="Cache-control"/>
#      <meta content="private" http-equiv="Cache-control"/>
#      <meta content="no-cache" http-equiv="Cache-control"/>
#      <meta content="no-store" http-equiv="Cache-control"/>
#      <div class="hidden" id="previewCameraContainer" role="complementary">
#       <div class="hidden" id="previewCameraCarousel">
#        <button class="previewCameraCarouselButton" id="previewCameraCarouselCloseButton" onclick="closeCarousel()" title="Close Preview Screen">
#         X
#        </button>
#        <button class="previewCameraCarouselButton" id="previewCameraCarouselPrevButton" onclick="carouselPrevious()" title="Next Preview Item">
#         Previous
#        </button>
#        <button class="previewCameraCarouselButton" id="previewCameraCarouselNextButton" onclick="carouselNext()" title="Next Preview Item">
#         Next
#        </button>
#        <h2 class="previewCameraCarouselButton" id="previewCameraCarouselTitle">
#         Currently Previewed Camera
#        </h2>
#        <img alt="Image displaying the current view of the camera being previewed." id="previewCameraCarouselCurrentImage">
#        </img>
#       </div>
#       <div id="previewCameraContent">
#       </div>
#      </div>
#      <!--Spacer exists so bottom of the screen is still visible-->
#      <div id="cameraPreviewSpacer">
#      </div>
#     </div>
#    </div>
#   </div>
#   <footer class="contentinfo" id="contentinfo" role="contentinfo">
#    <div class="bg-light">
#     <ul class="list-inline footer-nav">
#      <li class="list-inline-item">
#       <ul class="list-inline">
#        <li class="list-inline-item">
#         <a href="/twni/crown-copyright">
#          © Crown copyright
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a accesskey="8" href="/twni/terms-and-conditions">
#          Terms and conditions
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a href="/twni/privacy-statement">
#          Privacy
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a href="/twni/cookies">
#          Cookies
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a href="/twni/contacts">
#          Contacts
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a accesskey="3" href="/twni/site-map">
#          Site map
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a href="/twni/links">
#          Links
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a accesskey="0" href="/twni/accessibility">
#          Accessibility
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a href="https://www.nidirect.gov.uk" target="_blank">
#          NI Direct
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="list-inline-item footer-image-links">
#       <a href="/twni/liaison-with-others">
#        <img alt="Arc Atlantique and Connecting Europe logo" class="arc-atlantique-logo m-auto" id="arcAtlantiqueLogo" src="/twni/images/common/logo-arc-atlantique.png">
#         <img alt="" class="eu-logo m-auto" id="connectingEuropeLogo" src="/twni/images/common/logo-cef-horizontal.png">
#         </img>
#        </img>
#       </a>
#      </li>
#     </ul>
#     <a accesskey="S" href="#content" id="skip_navigation" title="Skip Navigation">
#     </a>
#    </div>
#   </footer>
#   <script src="/twni/javascript/twni/cctv.js?v=29092022">
#   </script>
#   <script src="/twni/javascript/twni/camera_preview.js?v=20241204">
#   </script>
#   <div>
#    <div class="modal" id="messageModal">
#     <div class="modal-content">
#      <h2 id="modalMessage">
#       Message placeholder
#      </h2>
#      <button class="close-btn" id="closeModalBtn">
#       Close
#      </button>
#     </div>
#    </div>
#   </div>
#   <script src="/twni/javascript/twni/floating_button.js?v=20241204">
#   </script>
#  </body>
# </html>

# %%
# From the above soup entity, there is a div with the id "cctvSelection" which contains the cameras; each camera element is in a div with the class "cctvOption"; and these cctv options are grouped into divs of class "camera-group" container, each with a header div "camera-group-name" which includes the name of the camera group. 
# Construct a dictionary of the cameras, with the camera group name as the key and a list of the cameras in that group as the value.

camera_groups = {}
for group in soup.find_all('div', class_='camera-group-container'):
    group_name = group.find('div', class_='camera-group-name').text
    cameras = group.find_all('div', class_='cctvOption')
    camera_groups[group_name] = cameras

print(camera_groups)
# Out:
# {'Greater Belfast': [<div class="cctvOption">
# <div class="imgrotate" id="imgrotate">
# <!-- First Link -->
# <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=44" id="cameraLink" title="View camera : A2 - Tillysburn">A2 - Tillysburn</a>
# <!-- Clickable Link -->
# <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=44', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
# <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : A2 - Tillysburn"/>
# </button>
# <!-- Button -->
# <button class="cameraPreviewAdd" onclick='addToPreview(44, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "3260.jpg", "A2 - Tillysburn")' title="Click here to add this camera to the Favourites Panel">
# <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
# </button>
# </div>
# </div>, <div class="cctvOption">
# <div class="imgrotate" id="imgrotate">
# <!-- First Link -->
# <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=45" id="cameraLink" title="View camera : A2 - Holywood Esplanade">A2 - Holywood Esplanade</a>
# <!-- Clickable Link -->
# <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=45', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
# <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : A2 - Holywood Esplanade"/>
# </button>
# <!-- Button -->
# <button class="cameraPreviewAdd" onclick='addToPreview(45, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "3261.jpg", "A2 - Holywood Esplanade")' title="Click here to add this camera to the Favourites Panel">
# <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
# </button>
# </div>
# </div>, <div class="cctvOption">
# <div class="imgrotate" id="imgrotate">
# <!-- First Link -->
# <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=9" id="cameraLink" title="View camera : A12 Clifton Street">A12 Clifton Street</a>
# <!-- Clickable Link -->
# <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=9', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
# <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : A12 Clifton Street"/>
# </button>
# <!-- Button -->
# <button class="cameraPreviewAdd" onclick='addToPreview(9, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "8.jpg", "A12 Clifton Street")' title="Click here to add this camera to the Favourites Panel">
# <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
# </button>
# </div>
# </div>, <div class="cctvOption">
# <div class="imgrotate" id="imgrotate">
# <!-- First Link -->
# <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=10" id="cameraLink" title="View camera : A12 Roden Street">A12 Roden Street</a>
# <!-- Clickable Link -->
# <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=10', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
# <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : A12 Roden Street"/>
# </button>
# <!-- Button -->
# <button class="cameraPreviewAdd" onclick='addToPreview(10, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "4.jpg", "A12 Roden Street")' title="Click here to add this camera to the Favourites Panel">
# <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
# </button>
# </div>
# </div>, <div class="cctvOption">
# <div class="imgrotate" id="imgrotate">
# <!-- First Link -->
# <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=171" id="cameraLink" title="View camera : M1 - Stockmans Lane">M1 - Stockmans Lane</a>
# <!-- Clickable Link -->
# <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=171', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
# <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : M1 - Stockmans Lane"/>
# </button>
# <!-- Button -->
# <button class="cameraPreviewAdd" onclick='addToPreview(171, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "106.jpg", "M1 - Stockmans Lane")' title="Click here to add this camera to the Favourites Panel">
# <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
# </button>
# </div>
# </div>, <div class="cctvOption">
# <div class="imgrotate" id="imgrotate">
# <!-- First Link -->
# <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=43" id="cameraLink" title="View camera : Saintfield Road - Primrose Hill">Saintfield Road - Primrose Hill</a>
# <!-- Clickable Link -->
# <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=43', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
# <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Saintfield Road - Primrose Hill"/>
# </button>
# <!-- Button -->
# <button class="cameraPreviewAdd" onclick='addToPreview(43, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "3259.jpg", "Saintfield Road - Primrose Hill")' title="Click here to add this camera to the Favourites Panel">
# <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
# </button>
# </div>
# </div>, <div class="cctvOption">
# <div class="imgrotate" id="imgrotate">
# <!-- First Link -->
# <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=191" id="cameraLink" title="View camera : Upper Knockbreda Rd - Cregagh Rd">Upper Knockbreda Rd - Cregagh Rd</a>
# <!-- Clickable Link -->
# <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=191', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
# <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Upper Knockbreda Rd - Cregagh Rd"/>
# </button>
# <!-- Button -->
# <button class="cameraPreviewAdd" onclick='addToPreview(191, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "404.jpg", "Upper Knockbreda Rd - Cregagh Rd")' title="Click here to add this camera to the Favourites Panel">
# <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
# </button>
# </div>
# </div>, <div class="cctvOption">
# <div class="imgrotate" id="imgrotate">
# <!-- First Link -->
# <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=156" id="cameraLink" title="View camera : East Bridge Street - Central Station">East Bridge Street - Central Station</a>
# <!-- Clickable Link -->
# <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=156', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
# <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : East Bridge Street - Central Station"/>
# </button>
# <!-- Button -->
# <button class="cameraPreviewAdd" onclick='addToPreview(156, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "21.jpg", "East Bridge Street - Central Station")' title="Click here to add this camera to the Favourites Panel">
# <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
# </button>
# </div>
# </div>, <div class="cctvOption">
# <div class="imgrotate" id="imgrotate">
# <!-- First Link -->
# <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=11" id="cameraLink" title="View camera : M1 Broadway">M1 Broadway</a>
# <!-- Clickable Link -->
# <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=11', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
# <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : M1 Broadway"/>
# </button>
# <!-- Button -->
# <button class="cameraPreviewAdd" onclick='addToPreview(11, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "3.jpg", "M1 Broadway")' title="Click here to add this camera to the Favourites Panel">
# <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
# </button>
# </div>
# </div>, <div class="cctvOption">
# <div class="imgrotate" id="imgrotate">
# <!-- First Link -->
# <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=190" id="cameraLink" title="View camera : Ballygowan Road - Knock Road">Ballygowan Road - Knock Road</a>
# <!-- Clickable Link -->
# <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=190', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
# <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Ballygowan Road - Knock Road"/>
# </button>
# <!-- Button -->
# <button class="cameraPreviewAdd" onclick='addToPreview(190, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "402_1.jpg", "Ballygowan Road - Knock Road")' title="Click here to add this camera to the Favourites Panel">
# <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
# </button>
# </div>
# </div>, <div class="cctvOption">
# <div class="imgrotate" id="imgrotate">
# <!-- First Link -->
# <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=54" id="cameraLink" title="View camera : Boucher Road - Tates Avenue">Boucher Road - Tates Avenue</a>
# <!-- Clickable Link -->
# <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=54', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
# <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera :
' title="Click here to add this camera to the Favourites Panel">
# <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
# </button>
# </div>
# </div>, <div class="cctvOption">
# <div class="imgrotate" id="imgrotate">
# <!-- First Link -->
# <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=197" id="cameraLink" title="View camera : Gortmerron Link Road, Dungannon">Gortmerron Link Road, Dungannon</a>
# <!-- Clickable Link -->
# <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=197', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
# <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Gortmerron Link Road, Dungannon"/>
# </button>
# <!-- Button -->
# <button class="cameraPreviewAdd" onclick='addToPreview(197, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "784.jpg", "Gortmerron Link Road, Dungannon")' title="Click here to add this camera to the Favourites Panel">
# <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
# </button>
# </div>
# </div>, <div class="cctvOption">
# <div class="imgrotate" id="imgrotate">
# <!-- First Link -->
# <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=198" id="cameraLink" title="View camera : Market Square, Dungannon">Market Square, Dungannon</a>
# <!-- Clickable Link -->
# <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=198', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
# <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Market Square, Dungannon"/>
# </button>
# <!-- Button -->
# <button class="cameraPreviewAdd" onclick='addToPreview(198, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "785.jpg", "Market Square, Dungannon")' title="Click here to add this camera to the Favourites Panel">
# <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
# </button>
# </div>
# </div>, <div class="cctvOption">
# <div class="imgrotate" id="imgrotate">
# <!-- First Link -->
# <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=200" id="cameraLink" title="View camera : Gaol Square, Enniskillen">Gaol Square, Enniskillen</a>
# <!-- Clickable Link -->
# <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=200', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
# <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : Gaol Square, Enniskillen"/>
# </button>
# <!-- Button -->
# <button class="cameraPreviewAdd" onclick='addToPreview(200, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "787.jpg", "Gaol Square, Enniskillen")' title="Click here to add this camera to the Favourites Panel">
# <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
# </button>
# </div>
# </div>]}

# %%
cameras[0]
# Out:
# <div class="cctvOption">
# <div class="imgrotate" id="imgrotate">
# <!-- First Link -->
# <a class="pb-1 text-nowrap text-truncate align-middle cctv-no-style" href="/twni/cameras/static?id=13" id="cameraLink" title="View camera : M1 Tamnamore">M1 Tamnamore</a>
# <!-- Clickable Link -->
# <button class="cameraNewTabLink" onclick="var childWindow = window.open('/twni/cameras/static?id=13', 'childWindow', 'width=700,height=600,top=100,left=100,scrollbars=yes,resizable=yes'); childWindow.focus();" title="Button to open the camera in a separate window" type="button">
# <img alt="open in new tab" src="/twni/images/pages/cameras_open_in_new_tab.png" title="View camera : M1 Tamnamore"/>
# </button>
# <!-- Button -->
# <button class="cameraPreviewAdd" onclick='addToPreview(13, "https:\/\/cctv.trafficwatchni.com", "1734545910000", "17.jpg", "M1 Tamnamore")' title="Click here to add this camera to the Favourites Panel">
# <img alt="Add" src="/twni/images/pages/wired-outline-49-plus-circle-static.png"/>
# </button>
# </div>
# </div>

# %%
# Extract the 'onclick' argument from the 'cameraPreviewAdd' button.
# The 'onclick' argument contains the camera id, a base url, a cache timestamp, camera image filename and a camera name.

camera = cameras[0]

def parse_cctvoption(camera):
    onclick = camera.find('button', class_='cameraPreviewAdd')['onclick']
    try:
        _, cctv_url, cache_key, file, camera_name = eval(onclick.replace("addToPreview", ""))
    except ValueError:
        print(f"Error parsing camera: {onclick}")
        raise
    camera_id = file.split("_")[0]
    return {
        "camera_id": camera_id,
        "cctv_url": f"https://cctv.trafficwatchni.com/{file}",
        "cache_key": cache_key,
        "file": file,
        "camera_name": camera_name
    }

parse_cctvoption(camera)
# Out:
# {'camera_id': '55.jpg',
#  'cctv_url': 'https://cctv.trafficwatchni.com/55.jpg',
#  'cache_key': '1734545910000',
#  'file': '55.jpg',
#  'camera_name': 'A2 Shore Rd - Trooperslane, Carrick'}

# %%
camera_groups = {}
for group in soup.find_all('div', class_='camera-group-container'):
    group_name = group.find('div', class_='camera-group-name').text
    cameras = group.find_all('div', class_='cctvOption')
    cameras = [{'camera_group':group_name, **parse_cctvoption(camera)} for camera in cameras]
    camera_groups[group_name] = cameras

print(camera_groups)
# Out:
# {'Greater Belfast': [{'camera_group': 'Greater Belfast', 'camera_id': '3260.jpg', 'cctv_url': 'https://cctv.trafficwatchni.com/3260.jpg', 'cache_key': '1734545910000', 'file': '3260.jpg', 'camera_name': 'A2 - Tillysburn'}, {'camera_group': 'Greater Belfast', 'camera_id': '3261.jpg', 'cctv_url': 'https://cctv.trafficwatchni.com/3261.jpg', 'cache_key': '1734545910000', 'file': '3261.jpg', 'camera_name': 'A2 - Holywood Esplanade'}, {'camera_group': 'Greater Belfast', 'camera_id': '8.jpg', 'cctv_url': 'https://cctv.trafficwatchni.com